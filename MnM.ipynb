# %%
### Missing No more

# %%
import pygame, time, script
import textwrap
pygame.init()

# Size of the screen
size = width, height = 1000, 600
grey = 128, 128, 128
white = 255, 255, 255
black = 0, 0, 0 

# Font size and type
title_font = pygame.font.Font('TitilliumWeb.ttf', 72)
menu_font = pygame.font.Font('TitilliumWeb.ttf', 32)
game_font = pygame.font.Font('TitilliumWeb.ttf', 28)
box_font = pygame.font.Font('TitilliumWeb.ttf', 15)

# background images
background = pygame.image.load('characters/splash.jpg')
background2 = pygame.image.load('characters/california.png')
# characters images
taye = pygame.image.load('characters/1.png')
mathhew = pygame.image.load('characters/2.png')
friend = pygame.image.load('characters/friend.png')

cindy = pygame.image.load('characters/4.png')
counter = 0
# location
california = pygame.image.load('characters/california.png')
school = pygame.image.load('characters/school.jpg')
house = pygame.image.load('characters/house.png')
room = pygame.image.load('characters/bedroom.png')
computer = pygame.image.load('characters/computer.png')
park = pygame.image.load('characters/park.jpg')

#characters
maria = pygame.image.load('characters/3.png')
kidnapper = pygame.image.load('characters/Kidnapper.png')



# Scene changer
game_script = 1
case = 1
game_running = True

location = {'california':california,'school':school,'house':house,'room':room,'computer':computer,'park':park}
character = {'maria':maria,'kidnapper':kidnapper}

#Display the application scrreen


# Starting screen
def menu_screen():
    
    global maria
    
    pygame.mixer.music.load('true.mp3')
    pygame.mixer.music.play(-1)
    background1 = pygame.transform.scale(background, (1000, 600))
    screen.blit(background1,[0,0])
    #start_button = pygame.draw.rect(screen, (black), pygame.Rect(410, 310, 180, 55))
    screen.blit(menu_font.render('Start game', 1, black), (425, 210))
    pygame.display.flip()
    done = True
    #char_1 = pygame.draw.rect(screen, (black), pygame.Rect(233, 100, 150, 150))
    #char_3 = pygame.draw.rect(screen, (black), pygame.Rect(233, 350, 150, 150))
    #char_2 = pygame.draw.rect(screen, (black), pygame.Rect(616, 100, 150, 150))
    #char_4 = pygame.draw.rect(screen, (black), pygame.Rect(616, 350, 150, 150))
    while done:
        event = pygame.event.poll()
            # if the 'close' button of the window is pressed
        if event.type == pygame.QUIT:
            done = False
            
        if event.type == pygame.MOUSEBUTTONDOWN:
            # prints on the console the pressed button and its position at that moment
            print('button {} pressed in the position {}'.format(event.button, event.pos))
            print(counter)
            if 410 < event.pos[0] < 590 and 210 < event.pos[1] < 265 and counter == 0:
                showchar()
 
            elif 110 < event.pos[0] < 340 and 110 < event.pos[1] < 260 and counter == 1:
                print(counter)
                scene1()
        
            elif 800 < event.pos[0] < 1000 and 550 < event.pos[1] < 600 and counter == 2:
                scene2()
                #scene6()
            
            elif 800 < event.pos[0] < 1000 and 550 < event.pos[1] < 600 and counter == 3:
                scene3()
                
            elif 800 < event.pos[0] < 1000 and 550 < event.pos[1] < 600 and counter == 4:
                scene4()
                
            elif 800 < event.pos[0] < 1000 and 550 < event.pos[1] < 600 and counter == 5 and case ==1:
                scene5(1)
            
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==2:
                scene5(2)
                
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==3:
                scene5(3)
                
            #elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==4:
               #scene5(4)
                
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==5:
                scene5(5)
                
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==6:
                scene5(6)
            
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==7:
                scene5(7)
                
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==8:
                scene5(8)
                
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==9:
                scene5(9)
                
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==10:
                scene5(10)
                
            elif 800 < event.pos[0] < 900 and 100 < event.pos[1] < 550 and counter == 5 and case ==11:
                scene5(11)
                
            elif 800 < event.pos[0] < 1000 and 550 < event.pos[1] < 600 and counter == 6:
                scene6()
                
            elif 600 < event.pos[0] < 1000 and 100 < event.pos[1] < 500 and counter == 7:
                scene7()
                
            elif 800 < event.pos[0] < 1000 and 550 < event.pos[1] < 600 and counter == 8:
                scene8()
                
def scaling(image,a,b):
    return pygame.transform.scale(image, (a,b))
            
def showchar():
    global counter
    background1 = pygame.transform.scale(background, (1000, 600))
    screen.blit(background1,[0,0])
    # Character selection
    screen.blit(pygame.transform.scale(maria,(140,140)),[150,110])
    screen.blit(pygame.transform.scale(taye,(140,140)),[340,110])
    screen.blit(pygame.transform.scale(mathhew,(140,140)),[520,110])
    screen.blit(pygame.transform.scale(cindy,(140,140)),[700,110])
    pygame.display.flip()
    counter = 1


    
def scene1():
    print("1")
    global game_script, location, character, counter
    turn = 0
    game_state = 1
    while game_state == 1:
        line = getattr(script,('scene'+str(game_script)))(turn)
        pygame.event.get()
        # checking for click state
        click_state = pygame.mouse.get_pressed()
        if turn == 0:
            scene_start= 0
            for i in range(4):
                if scene_start == 0 :
                    screen.fill(white)
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
                elif scene_start == 1:
                    time.sleep(1)
                    screen.blit(scaling(character[line[1]],160,150), [400,475])
                elif scene_start == 2:
                    time.sleep(1)
                    #pygame.draw.textbox(line[2], (140, 100, 900, 100))
                    pygame.draw.rect(screen, (grey), pygame.Rect(140, 100, 900, 100))
                elif scene_start == 3:
                    message_display(20, (140, 120), 50, line[2])
                    nextbutton()
                    turn += 1
                    clicked = 0
                    counter = 2
                scene_start += 1
                
            game_state = line[4]
                
def nextbutton():
    myfont = pygame.font.SysFont("monospace", 40)
    time.sleep(1)
    pygame.draw.rect(screen, (white),pygame.Rect(840,550,250,50))
    screen.blit(myfont.render('Next',1,black),(860,550))
    pygame.display.flip()
    
def scene2():
    print("2")
    
    global game_script, location, character, counter
    game_script = counter
    game_state = 1
    turn = 0
    while game_state == 1:
        line = getattr(script,('scene'+str(game_script)))(turn)
        pygame.event.get()
        # checking for click state
        click_state = pygame.mouse.get_pressed()
        if turn == 0:
            scene_start= 0
            for i in range(4):
                if scene_start == 0 :
                    screen.fill(white)
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
                elif scene_start == 2:
                    time.sleep(1)
                    pygame.draw.rect(screen, (grey), pygame.Rect(120, 423, 740, 120))
                elif scene_start == 3:
                    time.sleep(1)
                    message_display(20, (130, 423), 50, line[2])
                    nextbutton()
                    turn += 1
                    clicked = 0
                    counter = 3
                scene_start += 1
                pygame.display.flip()
            game_state = line[4]           
                   
        
        #screen.blit(pygame.transform.scale(background2, (1000, 600)),[0,0])
        #pygame.display.flip()
    
def scene3():
    print("3")
    
    global game_script, location, character, counter
    game_script = counter
    game_state = 1
    turn = 0
    while game_state == 1:
        line = getattr(script,('scene'+str(game_script)))(turn)
        pygame.event.get()
        # checking for click state
        click_state = pygame.mouse.get_pressed()
        if turn == 0:
            scene_start= 0
            for i in range(4):
                if scene_start == 0 :
                    screen.fill(white)
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
                elif scene_start == 2:
                    time.sleep(1)
                    pygame.draw.rect(screen, (grey), pygame.Rect(120, 423, 740, 120))
                elif scene_start == 3:
                    time.sleep(1)
                    message_display(20, (130, 423), 50, line[2])
                    nextbutton()
                    turn += 1
                    clicked = 0
                    counter = 4
                scene_start += 1
                pygame.display.flip()
            game_state = line[4]           
        
        #screen.blit(pygame.transform.scale(background2, (1000, 600)),[0,0])
        #pygame.display.flip()
    
def scene4():
    print("4")
    
    global game_script, location, character, counter
    game_script = counter
    game_state = 1
    turn = 0
    while game_state == 1:
        line = getattr(script,('scene'+str(game_script)))(turn)
        pygame.event.get()
        # checking for click state
        click_state = pygame.mouse.get_pressed()
        if turn == 0:
            scene_start= 0
            for i in range(4):
                if scene_start == 0 :
                    screen.fill(white)
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
                elif scene_start == 2:
                    time.sleep(1)
                    pygame.draw.rect(screen, (grey), pygame.Rect(120, 423, 740, 120))
                elif scene_start == 3:
                    time.sleep(1)
                    message_display(20, (130, 423), 50, line[2])
                    nextbutton()
                    turn += 1
                    clicked = 0
                    counter = 5
                scene_start += 1
                pygame.display.flip()
            game_state = line[4]           
        
        #screen.blit(pygame.transform.scale(background2, (1000, 600)),[0,0])
        #pygame.display.flip()
    

def scene5(case1):
    
    global game_script, location, character, counter, case
    
    screen.fill(white)
    screen.blit(scaling(computer,1000,600),[0,0])
    pygame.display.flip()
    if case1 == 1:
        pygame.draw.rect(screen, (grey), pygame.Rect(130, 523, 740, 120))
        message_display(20, (130, 530), 50, 'You log onto Friendsbook and start browsing through people’s pictures and posts')

        # image
        time.sleep(4)
        screen.blit(scaling(computer,1000,600),[0,0])
        pygame.display.flip()
        pygame.draw.rect(screen, (grey), pygame.Rect(120, 523, 740, 120))
        message_display(20, (130, 530), 50, "You see pictures of kids from your class having fun at the park.")

        # image
        
        time.sleep(4)
        screen.blit(scaling(computer,1000,600),[0,0])
        pygame.draw.rect(screen, (grey), pygame.Rect(120, 523, 740, 120))
        message_display(20, (130, 530), 50,'You wish you had a friend that you can go to park with.')
        # image

        time.sleep(4)
        screen.blit(scaling(computer,1000,600),[0,0])
        pygame.display.flip()
        pygame.draw.rect(screen, (grey), pygame.Rect(120, 523, 740, 120))
        message_display(20, (130, 530), 50,'Just then a friend request shows up.')

        # image

        time.sleep(2)
        text,textbox = textbox_wrap('Accept',800,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Reject',800,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Ignore',800,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        
        case = 2
        
    if case1 == 2:
        pygame.draw.rect(screen, (grey), pygame.Rect(130, 523, 740, 120))
        message_display(20, (130, 530), 50,'Jennifer : Hey I go to Westbridge. Just wanted to chat. Accept my friend request?')
        
        screen.blit(scaling(friend,150,150),[200,250])

        time.sleep(1)
        text,textbox = textbox_wrap('Accept',800,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Reject',800,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Ignore',800,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        case = 3
    
    if case1 == 3:
        time.sleep(1)
        text,textbox = textbox_wrap('Jennifer: Hi :)',100,100)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('A. Hey wassup?',800,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('B. um... hi',800,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('C. Who are you?',800,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        case = 5
        
 
        
    if case1 == 5:
        text,textbox = textbox_wrap('Jennifer: Hi :)',100,100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Hey wassup?',300,125)
        screen.blit(text,textbox)
        time.sleep(1)
        text,textbox = textbox_wrap('Jennifer: Hey I am Jennifer. I am in your History class.' ,100,150)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('A. oh cool',700,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('B. um.. ok',700,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('C. Really? Not seen you before',700,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        case = 6
        
    if case1 == 6:
        text,textbox = textbox_wrap('Jennifer: Hi :)',100,100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Hey wassup?',300,125)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey I am Jennifer. I am in your History class.' ,100,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You:  Really? Not seen you before.',300,175)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('Jennifer: I usually sit in the back. No one really notices me.' ,100,200)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap("Jennifer: So how did you do in Mrs Smith's test?." ,100,225)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('A. Great!',800,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('B. ok, I guess',800,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('C. Fine ....',800,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        case = 7
    if case1 == 7:
        text,textbox = textbox_wrap('Jennifer: Hi :)',100,100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Hey wassup?',300,125)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey I am Jennifer. I am in your History class.' ,100,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Really? Not seen you before',300,175)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: I usually sit in the back. No one really notices me.' ,100,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("Jennifer: So how did you do in Mrs Smith's test?." ,100,225)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("You: Great!" ,300,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('Jennifer: Ya, I think I did alright' ,100,275)
        screen.blit(text,textbox)
        time.sleep(2)
        text,textbox = textbox_wrap('Jennifer: Hey I noticed you were reading a comic in class? Fan?' ,100,300)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('A. Oh I love them!',750,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('B. Ya, Kinda',750,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('C. Why are you asking?',750,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        case = 8
        
    if case1 == 8:
        text,textbox = textbox_wrap('Jennifer: Hi :)',100,100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Hey wassup?',300,125)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey I am Jennifer. I am in your History class.' ,100,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You:  Really? Not seen you before',300,175)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: I usually sit in the back. No one really notices me.' ,100,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("Jennifer: So how did you do in Mrs Smith's test?." ,100,225)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("You: Great!" ,300,250)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Ya, I think I did alright' ,100,275)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey I noticed you were reading a comic in class? Fan?' ,100,300)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Oh I love them' ,300,325)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('Jennifer: Even I love them. Any favourites?' ,100,350)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('A. Oh I am a huge marvel fan',700,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('B. Probably Batman',700,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('C. Wonderwoman',700,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        case = 9
        
    if case1 ==9:
        text,textbox = textbox_wrap('Jennifer: Hi :)',100,100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Hey wassup?',300,125)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey I am Jennifer. I am in your History class.' ,100,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You:  Really? Not seen you before',300,175)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: I usually sit in the back. No one really notices me.' ,100,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("Jennifer: So how did you do in Mrs Smith's test?." ,100,225)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("You: Great!" ,300,250)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Ya, I think I did alright' ,100,275)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey I noticed you were reading a comic in class? Fan?' ,100,300)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Oh I love them' ,300,325)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Even I love them. Any favourites?' ,100,350)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Wonderwoman' ,300,375)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('Jennifer: Me too. We have a lot of similarities. We should be friends ' ,100,400)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('A. Yeah! Great idea',800,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('B. Hmm Maybe',800,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('C. I dont know',800,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        case = 10 
        
    if case1 ==10:
        text,textbox = textbox_wrap("Jennifer: So how did you do in Mrs Smith's test?." ,100,200-100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("You: Great!" ,300,225-100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Ya, I think I did alright' ,100,250-100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey I noticed you were reading a comic in class? Fan?' ,100,275-100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Oh I love them' ,300,300-100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Even I love them. Any favourites?' ,100,325-100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Wonderwoman' ,300,350-100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Me too. We have a lot of similarities. We should be friends ' ,100,375-100)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Yes! Great Idea!' ,300,400-100)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('Jennifer: We would have a great time talking about comics ' ,100,300+25)
        screen.blit(text,textbox)
        time.sleep(1)
        text,textbox = textbox_wrap('Jennifer: Hey! ' ,100,325+ 25)
        screen.blit(text,textbox)
        time.sleep(1)
        text,textbox = textbox_wrap("Jennifer: How about meeting up today? Everyone's at the park" ,100,350 + 25)
        screen.blit(text,textbox)
        time.sleep(2)
        text,textbox = textbox_wrap("Jennifer: We could meet there too and read comics. What do you say?" ,100,375 +25)
        screen.blit(text,textbox)
        time.sleep(1)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap('A. Ya Sure! Sounds Great',700,150)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('B. I need to ask my mom first',700,200)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('C. No thanks',700,250)
        screen.blit(text,textbox)
        pygame.display.flip()
        case = 11
        
    if case1 ==11:
        text,textbox = textbox_wrap("Jennifer: So how did you do in Mrs Smith's test?." ,100,200-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("You: Great!" ,300,225-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Ya, I think I did alright' ,100,250-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey I noticed you were reading a comic in class? Fan?' ,100,275-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Oh I love them' ,300,300-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Even I love them. Any favourites?' ,100,325-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Wonderwoman' ,300,350-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Me too. We have a lot of similarities. We should be friends ' ,100,375-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('You: Yes! Great Idea!' ,300,400-100-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: We would have a great time talking about comics ' ,100,300+25-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap('Jennifer: Hey! ' ,100,325+ 25-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("Jennifer: How about meeting up today? Everyone's at the park" ,100,350 + 25-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("Jennifer: We could meet there too and read comics. What do you say?" ,100,375 +25-75)
        screen.blit(text,textbox)
        text,textbox = textbox_wrap("You: Ya Sure! Sounds Great" ,300,425-75)
        screen.blit(text,textbox)
        pygame.display.flip()
        time.sleep(1)
        text,textbox = textbox_wrap("Jennifer: Great! I have to finish some homework first." ,100,425-75)
        screen.blit(text,textbox)
        time.sleep(2)
        text,textbox = textbox_wrap("Jennifer: I will see you at the park around 8ish. I'll be by the slide" ,100,450-75)
        screen.blit(text,textbox)
        time.sleep(2)
        text,textbox = textbox_wrap("You: Cool" ,300,475-75)
        screen.blit(text,textbox)
        nextbutton()
        counter = 6
        
        
        
        
        
        
    
    
    
def scene6():
    print("6")
    
    global game_script, location, character, counter
    game_script = counter
    game_state = 1
    turn = 0
    while game_state == 1:
        line = getattr(script,('scene'+str(game_script)))(turn)
        pygame.event.get()
        # checking for click state
        click_state = pygame.mouse.get_pressed()
        if turn == 0:
            scene_start= 0
            for i in range(4):
                if scene_start == 0 :
                    screen.fill(white)
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
                elif scene_start == 2:
                    time.sleep(1)
                    pygame.draw.rect(screen, (grey), pygame.Rect(120, 423, 740, 120))
                elif scene_start == 3:
                    time.sleep(1)
                    message_display(20, (130, 423), 50, line[2])
                    
                    text,textbox = textbox_wrap('A. Tell her where you’re going.',800,150)
                    screen.blit(text,textbox)
                    text,textbox = textbox_wrap('B. Sneak out since she doesn’t even notice you’re there',600,200)
                    screen.blit(text,textbox)
                    
                    pygame.display.flip()
                    
    
                    turn += 1
                    clicked = 0
                    counter = 7
                scene_start += 1
                pygame.display.flip()
            game_state = line[4]   
            
def scene7():
    print("7")
    
    global game_script, location, character, counter
    game_script = counter
    game_state = 1
    turn = 0
    while game_state == 1:
        line = getattr(script,('scene'+str(game_script)))(turn)
        pygame.event.get()
        # checking for click state
        click_state = pygame.mouse.get_pressed()
        if turn == 0:
            scene_start= 0
            for i in range(4):
                if scene_start == 0 :
                    screen.fill(white)
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
            
                    
                elif scene_start == 2:
                    time.sleep(1)
                    pygame.draw.rect(screen, (grey), pygame.Rect(120, 423, 740, 120))
                elif scene_start == 3:
                    time.sleep(1)
                    message_display(20, (130, 423), 50, line[2])
    
                    # image
                    time.sleep(2)
                    screen.fill(white)
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
                    pygame.display.flip()
                    time.sleep(1)
                    screen.blit(scaling(character[line[1]],150,150), [600,225])
                    pygame.display.flip()
                    time.sleep(2)
                    pygame.draw.rect(screen, (grey), pygame.Rect(120, 423, 740, 120))
                    message_display(20, (130, 430), 50, "There’s a strange man by the tree. He walks up to you. He says: “Hey Maria. I’m glad you could make it.")
                    
                    
                    
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
                    screen.blit(scaling(character[line[1]],150,150), [600,225])
                    pygame.draw.rect(screen, (grey), pygame.Rect(120, 423, 740, 120))
                    message_display(20, (130, 430), 50, "You respond: “Who are you?")
                    pygame.display.flip()
                    time.sleep(3)
                    screen.blit(scaling(location[line[0]],1000,600),[0,0])
                    screen.blit(scaling(character[line[1]],150,150), [600,225])
                    pygame.draw.rect(screen, (grey), pygame.Rect(120, 423, 740, 120))
                    message_display(20, (130, 430), 50, "He says: “I’m Jennifer. I’m here to be your friend.")
                    pygame.display.flip()
                    
                    nextbutton()
                    
                    turn += 1
                    clicked = 0
                    counter = 8
                scene_start += 1
                pygame.display.flip()
            game_state = line[4]
            
def scene8():
    print("8")
    
    global game_script, location, character, counter
    screen.fill(black)
    #message = "Here’s what you should have done: Don’t accept friend requests from people you don’t know. Don’t reveal too much about yourself to strangers online. Don’t agree to meet someone you met online. Always tell an adult where you are going. Ask permission. Pay attention to your surroundings. If you feel unsafe, talk to an adult or call 911."
    message = "Here is what you should have done:"
    message_display(20, (100, 10), 50, message)
    message1 = "*** Don't accept friend requests from people you don't know."
    message_display(20, (120, 80), 50, message1)
    message2 = "*** Don’t reveal too much about yourself to strangers online."
    message_display(20, (120, 160), 50, message2)
    message3 = "*** Don’t agree to meet someone you met online."
    message_display(20, (120, 240), 50, message3)
    message4 = "*** Always tell an adult where you are going. Ask permission."
    message_display(20, (120, 320), 50, message4)
    message5 = "*** If you feel unsafe, talk to an adult or call 911."
    message_display(20, (120, 400), 50, message5)
    
def textbox_wrap(string,a,b):
    textfont = pygame.font.SysFont("monospace", 15)
    text = textfont.render(string, True, white,grey)
    textRect = text.get_rect()
    textR = (a,b,textRect[2],textRect[3])
    return text,textR

    
def message_display(textvars, xy, wrap, message):
    message = wrap_text(message,wrap)
    for part in message.split('\n'):
         textfont = pygame.font.SysFont("monospace", 20)
         p = textfont.render(part, 1, white)
         screen.blit(p,(xy))
         lst = list(xy)
         lst[1] = lst[1]+ textvars
         xy = tuple(lst)
         pygame.display.flip()
        
def wrap_text(message, wraplimit):
    return textwrap.fill(message, wraplimit)

screen = pygame.display.set_mode(size)
menu_screen()
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html
